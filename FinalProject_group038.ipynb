# %% [markdown]
# # COGS 118A - Final Project

# %% [markdown]
# # Insert title here
#
# # Names
# - Thanh Bui
# - Zura Nebieridze
# - Janty Sphabmixay
# - Ingrid Altamirano
# - Tristan Romanov

# %% [markdown]
# # Abstract
# This section should be short and clearly stated. It should be a single paragraph <200 words.  It should summarize:
# - what your goal/problem is
# - what the data used represents
# - the solution/what you did
# - major results you came up with (mention how results are measured)
#
# __NB:__ this final project form is much more report-like than the proposal and the checkpoint. Think in terms of writing a paper with bits of code in the middle to make the plots/tables
#
# # Abstract (Old)
# Numer.ai provides us dataset with `id` that corresponds with a specific time, `era`. The `features` are the quantitative attributes of the stock at the time. The `target` reprensents an abstract measure of performance ~4 weeks into the future.
#
# In this project, we want to find a good model to predict the `target` using the past `features` in Numer.ai dataset. We will get datasets from Numer.ai and apply our Machine Learning algorithms that we learned from COGS118A. The success of our models will be measured based on how well the models were able to predict the `targets` using Regression Metrics. After that, we will compare all the models scores at the end to choose which one of the models would the "best" to fit the given dataset.

# %% [markdown]
# # Background
# ### Why Numerai?
#
# Numerai allows for crowdsource modeling in order to predict changes within the stock market. When data is encrypted the dataset is changed in a way where predictive structure is lost. Numerai allows data to be passed through without the loss of any predictive structures. The data is protected with a special encryption algorithm used to keep all of the data in a — structure. Numerai also allows us to combine a bunch of different models in order to determine various predictive structures.
#
# ### What is the Stock Market?
# As more and more people are looking for a way to invest, the stock market is one of the option people look at. <br>
# Stock market is where investors connect to buy and sell investments -- most commonly, stocks, which are shares of ownership in a public company[<sup>[1]</sup>](#stockinfo_link). Though, you do not need to be an "investor" to buy stock since it is open to everyone. <br>
# Stocks are usually purchased online through the stock market using a brokage account. Brokage account is an investmemt account that investors used to securely buy stocks. <br>
# ### How does it work?
# - Companies list shares of their stock on an exchange through a process called Initial Public Offering (IPO)[<sup>[1]</sup>](#stockinfo_link).
# - The companies able to raise their money to grow their business by having more investors buy into their shares.
# - Investors can later buy and sell those stocks among themselves and the exchange tracks the supply and demand of each listed stock which helps determine the price for each security[<sup>[1]</sup>](#stockinfo_link). <br>
#
# ### Why looking for good model?
# We are here to **help** people! <br>
# Stock prices are uncertain. Predicting stock prices is very important in business and in finance. We can use Data Science to come up with many different algorithms to help predict future values. The main reason to forecast stock prices is to help people who invest in stocks make better buying decision and companies to get a better view of how their businesses are going. <br>
#
# ### Prior Work 1 (Research)
# 1. A study forcasting stock market during COVID-19 used Long Short-Term Memory (LSTM) to predict future values and Recurrence Neural Network (RNN) model. They splitted their data into 80% training and 20% testing. For their historical data, they compared their date with 3-5 years data. Using their model, the stock price plunged 28% as more Covid-19 cases confirmed in Indenesia in March 2020.[<sup>[3]</sup>](#priorwork_2)
# 2. A study used a Machine Learning approach to predict the Stock Market. They used Regression, including Linear Regression, Polynomial Regression, Radial Basis Function (RBF) Regression, and Sigmoid Regression, to predict their model. Their goal is to help the "stock brokers and investors for investing money in the stock market" (Sharma, Bhuriya, Singh, 2017)[<sup>[4]</sup>](#priorwork_3)
# 3. A paper was published talking about using ML to predict the stock market. Here they used Regression and LSTM models to make prediction. They found hte LSTM model is more accurate compared to Regression based model[<sup>[5]</sup>](#priorwork_4).
# 4. Another study used the method called K-Nearest Neighbor to predict stock trend. They collected data over the duration of 8 years. They have multiple columns of open (starting value), high (peak value), low (lowest value), close (final worth), and volume (number of stock traded on a specific day) [<sup>[6]</sup>](#priorwork_5). <br>
#     * Compute the Stock Return *(This is essential to compare the present stock price and prior stock price)
#         * stock_return = (current_day_closing_price - closing_price_of_previous_day) / (previous_day_closing_proce_of_the_stock)
#     * Compute Z-Score
#         * z_score = open - (mean_of_open/stdv_of_open)
#     * Apply Z-Score for outlier detection
#     * Implementation of outlier removal using pandas code
#     * Apply K-Nearest Neighbours Classifiers
#
# ### Prior Work (Regarding ML Algorithms for Stock Prediction)
# #### Long Short-Term Memory (LSTM):
# - This is a deep learning artificial recurrent neural network architecture [<sup>[2]</sup>](#priorwork_1)
# - This method was created to predict Microsoft Corporation stock values <br>
# - This is used to make minor changes to the information by multiplying and adding[<sup>[2]</sup>](#priorwork_1)
#
# #### Time Series Analysis
# - Analyzes past data and find an estimate value for furure data
# - Non-linear function by recurrence relation derived from past values[<sup>[3]</sup>](#priorwork_2)
#
# #### Regression
# - Estimate relationships among variables (one dependent variable with multiple independent variables)
#
# #### K-Nearest Neighbors
# - Determine class of data point by majority votes
#
# ### Numerai Information
# Numerai is a global AI tournament, where participants compete against each other to build the best model that predicts the stock market using Machine Learning methods. Numerai provides the competitors with an encrypted dataset, initially a historical data set, and the competitors task is to build a model to predict the future target using live features, corresponding to the current stock market.[7] The users do this by training their data and making predictions on live weekly tournament data.[7]. This tournament runs on a weekly basis and it incentivizes users to compete through large monetary prizes. Numerai then uses all its submissions and winners model to create a “Meta Model”, which rules the capital of the Numerai hedge fund[7].

# %% [markdown]
# # Problem Statement
#
# Given numer.ai’s dataset of individual stocks characterized by numerical features, we want to predict a target feature measuring performance. Our problem is using current data to find the best model (within our abilities) to use for such a goal. “Best” will be operationalized by performance and generalizability, both of which can be evaluated numerically. Performance will be computed by a metric of prediction power: if we train our model on previously unseen stocks, how well will the targets be predicted? Such a metric will be defined as we explore the data. Since we are working with targets that represent performance, we will perhaps use a loss/reward function that does not penalize cases where the model predicts a high value for the target but the actual value is even higher. Or, we will not penalize these cases as much as those where the model predicts a high target value but the actual target value was low (or vice versa). That is, we will build a loss/reward function that cares more about predicting the direction of the target (positive or negative, high or low, above average or below average, etc.) than it cares about predicting the magnitude (very above average vs. extremely above average, etc.) of the target. Generalizability will be evaluated by “variance”: that means, the variance of the expected value of the generalization error. This is a metric commonly used to estimate generalizability, and is often the “variance” referred to in the “bias/variance tradeoff”. From this numerical measure we can make qualitative conclusions about our model’s propensity to overfit in the context of generalizability. These metrics will be computed by following scientific guidelines like randomization and partitioning (into train-validation-test). We will compute these metrics in a notebook that is runnable by graders.

# %% [markdown]
# # Data
#
# - https://numer.ai/data/v4
# - We are using the “V4 VALIDATION_PARQUET” dataset in the above link. It is a historical record of the prices of many stocks in 1191 features in 1006 eras, with 21 target features. 10 of the target features are measures of performance 20 days after the given era, 10 others are the same measures but 60 days after the given era, and one target feature is a duplicate of one of the twenty. They provide the 20 others to help with training.
# - For the focus of this projet, we will only be using 2 eras which leaves us with a dataset of 9621 data points, as using the whole dataset is very large (approx 2224922 data points).
# - Observations are indexed by the stock. Each contains the era of recording, the 1991 features about that stock, and the 21 target features. We will be unable to track this particular stock over time: each observation has a unique ID.
# - All data are obfuscated. That means the company makes sure we do not know what stocks we are working with, or what the variables correspond to. All features are either float64 or int8. The era variable is somewhat interpretable. The company was first hesitant to admit the resolution or sequential details of the variable, but they are now saying that each era is a week, and the eras are sequential (era 2 starts after era 1, but they share 60% overlap). Otherwise, the features are regularized and their names are meaningless (they are named “feature_untidy_withdrawn_bargeman” or something similarly uninterpretable). There exists NaN values, which we go into detail below.
# - We will work with modeling one era at a time as you cannot track a single stock’s performance across eras. This makes each era approx 4,800 rows by 1214 columns, and the entire dataset 9,621 rows by 1214 columns, where 21 of those columns are target features.

# %%
# Import stuff that we will need later
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Loading Data
# We'll load our dataset and take a look at our dataset!

# %%
# Loading data
original_df = pd.read_csv('data.csv')

# Take a look at our dataset
print("Data Shape:", original_df.shape)
print("Null Items in Data Set:", original_df.isna().sum().sum())
original_df.head(8)
# Out:
# Data Shape: (9621, 1215)
# Null Items in Data Set: 673
#                  id  era   data_type  \
# 0  n000101811a8a843  575  validation
# 1  n001e1318d5072ac  575  validation
# 2  n002a9c5ab785cbb  575  validation
# 3  n002ccf6d0e8c5ad  575  validation
# 4  n0051ab821295c29  575  validation
# 5  n008361ac9e9bd47  575  validation
# 6  n009e95486e1d64c  575  validation
# 7  n00b093a02b84295  575  validation
#
#    feature_honoured_observational_balaamite  feature_polaroid_vadose_quinze  \
# 0                                      0.50                             0.0
# 1                                      0.25                             1.0
# 2                                      0.25                             0.5
# 3                                      0.50                             1.0
# 4                                      0.50                             0.0
# 5                                      0.25                             1.0
# 6                                      1.00                             1.0
# 7                                      0.25                             0.5
#
#    feature_untidy_withdrawn_bargeman  feature_genuine_kyphotic_trehala  \
# 0                               1.00                              0.00
# 1                               0.50                              0.50
# 2                               0.50                              0.75
# 3                               0.50                              1.00
# 4                               0.00                              0.25
# 5                               0.50                              0.50
# 6                               1.00                              1.00
# 7                               0.75                              0.50
#
#    feature_unenthralled_sportful_schoolhouse  \
# 0                                       0.75
# 1                                       0.25
# 2                                       0.25
# 3                                       0.50
# 4                                       0.00
# 5                                       0.00
# 6                                       0.25
# 7                                       0.50
#
#    feature_divulsive_explanatory_ideologue  feature_ichthyotic_roofed_yeshiva  \
# 0                                     0.00                               1.00
# 1                                     0.75                               0.75
# 2                                     0.25                               0.75
# 3                                     1.00                               0.75
# 4                                     1.00                               0.50
# 5                                     0.75                               1.00
# 6                                     0.75                               1.00
# 7                                     0.25                               0.75
#
#    ...  target_paul_v4_20  target_paul_v4_60  target_george_v4_20  \
# 0  ...               0.50               0.50                 0.50
# 1  ...               0.00               0.25                 0.00
# 2  ...               0.50               0.75                 0.50
# 3  ...               0.25               0.00                 0.25
# 4  ...               0.50               0.50                 0.50
# 5  ...               0.50               0.50                 0.50
# 6  ...               0.50               0.50                 0.50
# 7  ...               0.75               1.00                 0.50
#
#    target_george_v4_60  target_william_v4_20  target_william_v4_60  \
# 0                 0.50              0.666667              0.500000
# 1                 0.50              0.166667              0.333333
# 2                 0.75              0.500000              0.666667
# 3                 0.00              0.166667              0.166667
# 4                 0.50              0.500000              0.500000
# 5                 0.50              0.500000              0.500000
# 6                 0.50              0.500000              0.500000
# 7                 0.75              0.666667              1.000000
#
#    target_arthur_v4_20  target_arthur_v4_60  target_thomas_v4_20  \
# 0             0.500000             0.500000             0.666667
# 1             0.333333             0.166667             0.166667
# 2             0.500000             0.666667             0.500000
# 3             0.333333             0.500000             0.333333
# 4             0.500000             0.500000             0.500000
# 5             0.333333             0.500000             0.500000
# 6             0.666667             0.500000             0.500000
# 7             0.500000             0.833333             0.666667
#
#    target_thomas_v4_60
# 0             0.500000
# 1             0.333333
# 2             0.666667
# 3             0.166667
# 4             0.500000
# 5             0.500000
# 6             0.500000
# 7             0.833333
#
# [8 rows x 1215 columns]

# %% [markdown]
# ### Data Cleaning
# Our dataset has quite a lot of `Null` datapoints, 673 to be exact! <br>
# Our group decided to drop these datapoint instead of replacing it with 0 since having it as 0 might affect our prediction later. <br>
# Moreover, if you are looking at our dataset, there is a column called `data_type`. We will not be using this column at all in our EDA, hence we will also drop this column.

# %%
# Dropping null data
original_df = original_df.dropna()

# Drop the data_type column since we will not use it in our EDA
original_df = original_df.drop(columns=['data_type'])

# Look at our dataset (now, after cleaning)
print("Data Shape (Now):", original_df.shape)
print("Null Items in Data Set (Now):", original_df.isna().sum().sum())
original_df.head(8)
# Out:
# Data Shape (Now): (9566, 1214)
# Null Items in Data Set (Now): 0
#                  id  era  feature_honoured_observational_balaamite  \
# 0  n000101811a8a843  575                                      0.50
# 1  n001e1318d5072ac  575                                      0.25
# 2  n002a9c5ab785cbb  575                                      0.25
# 3  n002ccf6d0e8c5ad  575                                      0.50
# 4  n0051ab821295c29  575                                      0.50
# 5  n008361ac9e9bd47  575                                      0.25
# 6  n009e95486e1d64c  575                                      1.00
# 7  n00b093a02b84295  575                                      0.25
#
#    feature_polaroid_vadose_quinze  feature_untidy_withdrawn_bargeman  \
# 0                             0.0                               1.00
# 1                             1.0                               0.50
# 2                             0.5                               0.50
# 3                             1.0                               0.50
# 4                             0.0                               0.00
# 5                             1.0                               0.50
# 6                             1.0                               1.00
# 7                             0.5                               0.75
#
#    feature_genuine_kyphotic_trehala  \
# 0                              0.00
# 1                              0.50
# 2                              0.75
# 3                              1.00
# 4                              0.25
# 5                              0.50
# 6                              1.00
# 7                              0.50
#
#    feature_unenthralled_sportful_schoolhouse  \
# 0                                       0.75
# 1                                       0.25
# 2                                       0.25
# 3                                       0.50
# 4                                       0.00
# 5                                       0.00
# 6                                       0.25
# 7                                       0.50
#
#    feature_divulsive_explanatory_ideologue  feature_ichthyotic_roofed_yeshiva  \
# 0                                     0.00                               1.00
# 1                                     0.75                               0.75
# 2                                     0.25                               0.75
# 3                                     1.00                               0.75
# 4                                     1.00                               0.50
# 5                                     0.75                               1.00
# 6                                     0.75                               1.00
# 7                                     0.25                               0.75
#
#    feature_waggly_outlandish_carbonisation  ...  target_paul_v4_20  \
# 0                                     0.25  ...               0.50
# 1                                     0.00  ...               0.00
# 2                                     0.00  ...               0.50
# 3                                     0.50  ...               0.25
# 4                                     0.25  ...               0.50
# 5                                     0.50  ...               0.50
# 6                                     1.00  ...               0.50
# 7                                     1.00  ...               0.75
#
#    target_paul_v4_60  target_george_v4_20  target_george_v4_60  \
# 0               0.50                 0.50                 0.50
# 1               0.25                 0.00                 0.50
# 2               0.75                 0.50                 0.75
# 3               0.00                 0.25                 0.00
# 4               0.50                 0.50                 0.50
# 5               0.50                 0.50                 0.50
# 6               0.50                 0.50                 0.50
# 7               1.00                 0.50                 0.75
#
#    target_william_v4_20  target_william_v4_60  target_arthur_v4_20  \
# 0              0.666667              0.500000             0.500000
# 1              0.166667              0.333333             0.333333
# 2              0.500000              0.666667             0.500000
# 3              0.166667              0.166667             0.333333
# 4              0.500000              0.500000             0.500000
# 5              0.500000              0.500000             0.333333
# 6              0.500000              0.500000             0.666667
# 7              0.666667              1.000000             0.500000
#
#    target_arthur_v4_60  target_thomas_v4_20  target_thomas_v4_60
# 0             0.500000             0.666667             0.500000
# 1             0.166667             0.166667             0.333333
# 2             0.666667             0.500000             0.666667
# 3             0.500000             0.333333             0.166667
# 4             0.500000             0.500000             0.500000
# 5             0.500000             0.500000             0.500000
# 6             0.500000             0.500000             0.500000
# 7             0.833333             0.666667             0.833333
#
# [8 rows x 1214 columns]

# %% [markdown]
# ### Data Visualization
# We'll explore our data first by visualizing what is happening in our dataset right now.

# %%
era_unique_list = original_df.era.unique()

# We will test our first era and use the second era to compare
era_1_df = original_df.loc[original_df.era == era_unique_list[0]]
era_2_df = original_df.loc[original_df.era == era_unique_list[1]]

features = [f for f in list(original_df) if 'feature' in f]    # Getting feature columns
targets = [t for t in list(original_df) if 'target' in t]      # Getting target columns

# %% [markdown]
# We'll also look at our targets dataset to see if there is anything interesting shows up.

# %%
# Countplot Targets
def plot_target_correlation(df, targets):
    for i, col in enumerate(targets):
        plt.figure(i)
        sns.countplot(x=col, data=df, palette='RdBu_r')

plot_target_correlation(era_1_df, targets)
# Out:
# C:\Users\Thanh Bui\AppData\Local\Temp\ipykernel_516\2678979712.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(i)

# %% [markdown]
# ### Understanding our Target Data
#
# From the plots, we can see a gaussian-like visual representation of our 21 targets, which we are predicting. We can see that these targets are highest at around .5. Now lets take a deeper look at the inside of our data, beginning with the first era. We will be splitting our dataset to era 0575, and run our baseline linear regression on this dataset. Later on, we will be using our second era for testing purposes.

# %%
for i in range(len(targets)):
    print(targets[i])
    print(era_1_df[targets[i]].value_counts())
# Out:
# target
# 0.50    2384
# 0.75     958
# 0.25     958
# 0.00     239
# 1.00     238
# Name: target, dtype: int64
# target_nomi_v4_20
# 0.50    2384
# 0.75     958
# 0.25     958
# 0.00     239
# 1.00     238
# Name: target_nomi_v4_20, dtype: int64
# target_nomi_v4_60
# 0.50    2374
# 0.75     961
# 0.25     961
# 0.00     241
# 1.00     240
# Name: target_nomi_v4_60, dtype: int64
# target_jerome_v4_20
# 0.50    2387
# 0.25     960
# 0.75     954
# 1.00     239
# 0.00     237
# Name: target_jerome_v4_20, dtype: int64
# target_jerome_v4_60
# 0.50    2385
# 0.25     961
# 0.75     956
# 1.00     239
# 0.00     236
# Name: target_jerome_v4_60, dtype: int64
# target_janet_v4_20
# 0.50    2407
# 0.25     947
# 0.75     946
# 0.00     240
# 1.00     237
# Name: target_janet_v4_20, dtype: int64
# target_janet_v4_60
# 0.50    2403
# 0.25     951
# 0.75     947
# 0.00     238
# 1.00     238
# Name: target_janet_v4_60, dtype: int64
# target_ben_v4_20
# 0.50    2394
# 0.75     956
# 0.25     955
# 1.00     236
# 0.00     236
# Name: target_ben_v4_20, dtype: int64
# target_ben_v4_60
# 0.50    2383
# 0.25     959
# 0.75     958
# 0.00     239
# 1.00     238
# Name: target_ben_v4_60, dtype: int64
# target_alan_v4_20
# 0.50    2488
# 0.25     908
# 0.75     904
# 0.00     239
# 1.00     238
# Name: target_alan_v4_20, dtype: int64
# target_alan_v4_60
# 0.50    2445
# 0.75     930
# 0.25     928
# 0.00     239
# 1.00     235
# Name: target_alan_v4_60, dtype: int64
# target_paul_v4_20
# 0.50    2395
# 0.25     958
# 0.75     955
# 0.00     238
# 1.00     231
# Name: target_paul_v4_20, dtype: int64
# target_paul_v4_60
# 0.50    2401
# 0.25     953
# 0.75     945
# 0.00     241
# 1.00     237
# Name: target_paul_v4_60, dtype: int64
# target_george_v4_20
# 0.50    2386
# 0.75     961
# 0.25     959
# 0.00     238
# 1.00     233
# Name: target_george_v4_20, dtype: int64
# target_george_v4_60
# 0.50    2394
# 0.25     957
# 0.75     956
# 0.00     237
# 1.00     233
# Name: target_george_v4_60, dtype: int64
# target_william_v4_20
# 0.500000    1880
# 0.333333    1052
# 0.666667     963
# 0.833333     334
# 0.166667     297
# 1.000000     157
# 0.000000      94
# Name: target_william_v4_20, dtype: int64
# target_william_v4_60
# 0.500000    1837
# 0.333333    1103
# 0.666667    1012
# 0.833333     305
# 0.166667     271
# 1.000000     157
# 0.000000      92
# Name: target_william_v4_60, dtype: int64
# target_arthur_v4_20
# 0.500000    2312
# 0.333333     942
# 0.666667     857
# 0.166667     269
# 0.833333     260
# 1.000000      82
# 0.000000      55
# Name: target_arthur_v4_20, dtype: int64
# target_arthur_v4_60
# 0.500000    2199
# 0.333333     989
# 0.666667     932
# 0.833333     260
# 0.166667     256
# 1.000000      93
# 0.000000      48
# Name: target_arthur_v4_60, dtype: int64
# target_thomas_v4_20
# 0.500000    2105
# 0.333333    1066
# 0.666667     888
# 0.833333     271
# 0.166667     262
# 1.000000     120
# 0.000000      65
# Name: target_thomas_v4_20, dtype: int64
# target_thomas_v4_60
# 0.500000    1982
# 0.333333    1139
# 0.666667     949
# 0.833333     240
# 0.166667     233
# 1.000000     147
# 0.000000      87
# Name: target_thomas_v4_60, dtype: int64

# %% [markdown]
# # Proposed Solution
#
# In this section, clearly describe a solution to the problem. The solution should be applicable to the project domain and appropriate for the dataset(s) or input(s) given. Provide enough detail (e.g., algorithmic description and/or theoretical properties) to convince us that your solution is applicable. Make sure to describe how the solution will be tested.
#
# If you know details already, describe how (e.g., library used, function calls) you plan to implement the solution in a way that is reproducible.
#
# If it is appropriate to the problem statement, describe a benchmark model<a name="sota"></a>[<sup>[3]</sup>](#sotanote) against which your solution will be compared.
#
# # Proposed Solution (Old)
#
# - We will **first** explore the data through **linear regression, as a base model**.  As we described above in the Data section, we will be building models on only single eras (~4800 rows) at a time. Then compare them against each other once getting a deeper understanding.
# - We propose the following as a solution. We will **seek to build a model** that takes any stock (in a single era) and predict its target. Since we will be predicting 1 target with 1191 predictors, we have extraordinary flexibility. We can assume that the target is a linear function of its predictors, and thus model the relationship by a high-dimensional line with *linear regression*. This will be our base model. We will also use regularization techniques like *decision tree regressors* to predict important features along with pruning methods: it would be nice to find a few features that are very predictive of the target. We will also incorporate a *logistic regression model*, to help compare these important predictive features. These models will then be compared to our `second era`, which we will use to test our results of our first model.
# - Our methods will be tested by splitting our dataset into train-validation-test partitions. The test partition will not be used to train our models or to tune hyperparameters: it will only be used to evaluate final models. We will do this all in a notebook that is runnable by graders.
# - By inspecting the dataset, you will notice that the data only take on a discrete number of values. For example, the target, and all of the predictors take on values 0, 0.25, 0.50, 0.75 and 1. These are numeric, but we can think of them as ordinal (or even ratio) categories. Also, the distribution of target values is exactly the same for every era: 5% are 0, 20% are 0.25, 50% are 0.50, 20% are 0.75, and 5% are 1 (this is by Numerai's obfuscation of the dataset and not by our construction). For our base model, we will perform linear regression of the target on all 1191 predictors to learn the regression coefficients. During test time, we will predict the target using the linear combination learned in training, and then we will compute the 5th, 25th (5+20), 75th (5+20+50), 95th (5+20+50+20), and 100th percentiles of the predictions, and then classify our predictions as class 0, 0.25, 0.50, 0.75, or 1, depending on which percentiles the prediction falls in between.
# - The regression+classification model described in the bullet above will be our base model. Since it is a classifier, it will be compared to other classifiers, which we will develop as the quarter progresses.

# %% [markdown]
# # Evaluation Metrics (Old)
#
# As described above, we will choose metrics to calculate our accuracy scores then decide which one of our models would be best to predict our dataset.
#
# We will our models on one era and then evaluate its performance on another era.
#
# Even though our target is numeric, this is a classification task, because there are 5 discrete categories. The distribution of the target is described above, and rewritten here for convenience: in any era, of the target values, 5% are 0, 20% are 0.25, 50% are 0.50, 20% are 0.75, and 5% are 1. Thus, a classifier that always predicts 0.50 will predict 50% of the targets correctly over any era. This is the "chance level" of **Accuracy** that we will try to beat. **Accuracy** is the objective function by which we will ultimately compare our model performances to each other (and the chance level).
#
# While **Accuracy** will be our final evaluation metric, we would also like to keep track of other measures of goodness to assist in development. Since we only have 5 target categories, it is feasible to compute **one-vs-rest accuracy** for every model that we would like to evaluate. That is, once a model generates class predictions, for each class, we will call it the positive class, and call the rest of the classes negative, and then compute **accuracy**. We will use this to see if the model is paying too much attention to the big class and not enough attention to the small classes.
#
# Another metric we will use during development is **predicted shape**, the distribution of the predicted values. We know what the shape is supposed to be; analyzing our predicted values' distributions' adherences to the correct shape will be crucial to understanding models.

# %% [markdown]
# # Results
#
# You may have done tons of work on this. Not all of it belongs here.
#
# Reports should have a __narrative__. Once you've looked through all your results over the quarter, decide on one main point and 2-4 secondary points you want us to understand. Include the detailed code and analysis results of those points only; you should spend more time/code/plots on your main point than the others.
#
# If you went down any blind alleys that you later decided to not pursue, please don't abuse the TAs time by throwing in 81 lines of code and 4 plots related to something you actually abandoned.  Consider deleting things that are not important to your narrative.  If its slightly relevant to the narrative or you just want us to know you tried something, you could keep it in by summarizing the result in this report in a sentence or two, moving the actual analysis to another file in your repo, and providing us a link to that file.
#
# ### Subsection 1
#
# You will likely have different subsections as you go through your report. For instance you might start with an analysis of the dataset/problem and from there you might be able to draw out the kinds of algorithms that are / aren't appropriate to tackle the solution.  Or something else completely if this isn't the way your project works.
#
# ### Subsection 2
#
# Another likely section is if you are doing any feature selection through cross-validation or hand-design/validation of features/transformations of the data
#
# ### Subsection 3
#
# Probably you need to describe the base model and demonstrate its performance.  Maybe you include a learning curve to show whether you have enough data to do train/validate/test split or have to go to k-folds or LOOCV or ???
#
# ### Subsection 4
#
# Perhaps some exploration of the model selection (hyper-parameters) or algorithm selection task. Validation curves, plots showing the variability of perfromance across folds of the cross-validation, etc. If you're doing one, the outcome of the null hypothesis test or parsimony principle check to show how you are selecting the best model.
#
# ### Subsection 5
#
# Maybe you do model selection again, but using a different kind of metric than before?

# %%
# We will perform our model on first era
X_1 = era_1_df[features]
y_1 = era_1_df[targets]

# And compare again with the second era
X_2 = era_2_df[features]
y_2 = era_2_df[targets]

# Getting shape to understand what are we dealing with
print("First Era:", era_unique_list[0])
print("X_1 Shape:", X_1.shape)  
print("y_1 Shape:", y_1.shape)
# Out:
# First Era: 575
# X_1 Shape: (4777, 1191)
# y_1 Shape: (4777, 21)

# %% [markdown]
# ### Multiple Linear Regression
# We will be predicting 1 target with 1191 predictors. We assume that the target is a linear function of its predictors, and thus model the relationship by a high-dimensional line with linear regression. We will use LinearRegression() method to create a linear regression object and got our independent and dependent training values in as parameters into our regression model. Once we have our regression model fitted, we can predict using our test set. We will return coefficients to see the relationship. <br>
#
# Our finding (Multiple Linear Regression):
# 1. First getting all the coefficients of the training_features (predictors) and taking the mean to see if on average of our training_targets would increase or decrease. The **result** we got was **negative** meaning that our training_targets decreases by that many factor on average.
# 2. We also look at the Mean Square Error (as our Metric) to see if our prediction was good/bad compared to the expected. If our score is close to 0, that implies our predictions are good. The **result** that we got are around **0.05 - 0.01** which implies that our predictions are very good compared to the expected values.

# %%
# Create empty lists to append later
linreg_score_list = []
coef_list = []

def linear_reg(X_train, y_train, X_test, y_test):

    # Define model
    model = LinearRegression()
    # Fit our training data to our model
    clf = model.fit(X_train, y_train)
    # Predict on test set
    y_pred = clf.predict(X_test)

    # Getting MSE
    linear_reg_score = mean_squared_error(y_test, y_pred)
    # Getting coefficients
    coefficient = clf.coef_ 

    return linear_reg_score, coefficient

for i in range(len(targets)):
  
  y = era_1_df[targets[i]]  # Loop through all targets

  X_train, X_test, y_train, y_test = train_test_split(X_1, y, test_size=0.33, train_size = 0.66, random_state=42)
  acc_score, coefficient = linear_reg(X_train, y_train, X_test, y_test)
  
  linreg_score_list.append(acc_score)
  coef_list.append(coefficient.mean())

target_score = list(zip(targets, linreg_score_list, coef_list))
linReg_score_df = pd.DataFrame(target_score, columns=['Targets', 'Linear_Reg_Score','coefficient avg'])

linReg_score_df
# Out:
#                  Targets  Linear_Reg_Score  coefficient avg
# 0                 target          0.075241        -0.000168
# 1      target_nomi_v4_20          0.075241        -0.000168
# 2      target_nomi_v4_60          0.079289        -0.000366
# 3    target_jerome_v4_20          0.075127        -0.000124
# 4    target_jerome_v4_60          0.079336        -0.000245
# 5     target_janet_v4_20          0.094135        -0.000135
# 6     target_janet_v4_60          0.101218        -0.000287
# 7       target_ben_v4_20          0.078865        -0.000196
# 8       target_ben_v4_60          0.079664        -0.000182
# 9      target_alan_v4_20          0.093107        -0.000234
# 10     target_alan_v4_60          0.098923        -0.000125
# 11     target_paul_v4_20          0.072494        -0.000097
# 12     target_paul_v4_60          0.075359        -0.000149
# 13   target_george_v4_20          0.065252        -0.000101
# 14   target_george_v4_60          0.069965        -0.000167
# 15  target_william_v4_20          0.056078        -0.000025
# 16  target_william_v4_60          0.060353        -0.000159
# 17   target_arthur_v4_20          0.056615         0.000032
# 18   target_arthur_v4_60          0.062030        -0.000081
# 19   target_thomas_v4_20          0.050215        -0.000074
# 20   target_thomas_v4_60          0.056925        -0.000178

# %% [markdown]
# ### Decision Tree Implementation
# After seeing positive scores in Linear Regression, indicating a sort of correlation we wanted to try to understand what are the most important and relevent features that predict our data. As we have over 1000 predictors, we can use a decision tree regressor for each target, to figure out if any predictors stand out. We took out the top 20, in descending order, are results are as follows. We will calculate our accuracy, using cross validation with a 5 k fold. We will be comparing this to the r^2 score and see if there are anything that pops out.

# %%
# Method to build decision Tree Regress Model 
def decisionTreeRegress(X_train, X_test,y_train, y_test): 
    regr1 = DecisionTreeRegressor(max_depth = 4, random_state=0)
    clf = regr1.fit(X_train, y_train)
    regr1_pred = regr1.predict(X_test)
    
    #Perform 5-fold cross validation 
    crossScores = cross_val_score(estimator=clf, X=X_train, y=y_train, cv=5)

    #Compute r^2 score 
    scores = clf.score(X_test, y_test)
    
    #getting parameters 
    getParams = clf.get_params

    #pull out top 20 important features, descending order
    for importance, name in sorted(zip(clf.feature_importances_, X_train.columns),reverse=True)[:20]:
         print(name, importance)

    return crossScores, scores, getParams

# Create empty lists to append later
crossValScoreList = [] 
actualScoresList = []

for i in range(len(targets)):
  
  y = era_1_df[targets[i]]  

  X_train, X_test, y_train, y_test = train_test_split(X_1, y, test_size=0.33, train_size = 0.66, random_state=42)

  crossValScore, acc_score, paramDetails = decisionTreeRegress(X_train, X_test, y_train, y_test)
  
  #avg cross val score 
  crossValScoreList.append(crossValScore.mean())

  #r^2 score for each i 
  actualScoresList.append(acc_score)
  
crossValZip = list(zip(targets,crossValScoreList, actualScoresList))
ValScore_df = pd.DataFrame(crossValZip, columns=['Targets', 'CrossValScoresMean', 'Scores'])

ValScore_df
# Out:
# feature_theocentric_shameful_quintuplet 0.10689360376479817
# feature_monocyclic_galliambic_par 0.09690197605026812
# feature_crookback_workable_infringement 0.08898447427306044
# feature_khedival_viewable_bloodlust 0.08616021631082363
# feature_woodier_slimmest_supplanter 0.07452874052388263
# feature_isobilateral_olden_nephron 0.07140965113936128
# feature_unsinkable_dumbstruck_octuplet 0.06583249207585384
# feature_brief_optimistic_consentaneity 0.06195452041562837
# feature_narcotized_collectivist_evzone 0.06112636594261552
# feature_contraceptive_cartelist_beast 0.056900469932326087
# feature_dwarfish_isochronal_amateur 0.05503207156062585
# feature_undisguised_photoelectric_floorboard 0.04743279436202343
# feature_paleolithic_myalgic_lech 0.04594179358696227
# feature_associable_additional_bough 0.041926840782528375
# feature_fremd_cricoid_gibberellin 0.03897398927924199
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_theocentric_shameful_quintuplet 0.10689360376479817
# feature_monocyclic_galliambic_par 0.09690197605026812
# feature_crookback_workable_infringement 0.08898447427306044
# feature_khedival_viewable_bloodlust 0.08616021631082363
# feature_woodier_slimmest_supplanter 0.07452874052388263
# feature_isobilateral_olden_nephron 0.07140965113936128
# feature_unsinkable_dumbstruck_octuplet 0.06583249207585384
# feature_brief_optimistic_consentaneity 0.06195452041562837
# feature_narcotized_collectivist_evzone 0.06112636594261552
# feature_contraceptive_cartelist_beast 0.056900469932326087
# feature_dwarfish_isochronal_amateur 0.05503207156062585
# feature_undisguised_photoelectric_floorboard 0.04743279436202343
# feature_paleolithic_myalgic_lech 0.04594179358696227
# feature_associable_additional_bough 0.041926840782528375
# feature_fremd_cricoid_gibberellin 0.03897398927924199
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_unappreciated_humiliated_misapprehension 0.10921023243318664
# feature_interconnected_correlatable_exogamy 0.10417226000908718
# feature_unconfessed_paltry_finn 0.085132590192021
# feature_testicular_slashed_ventosity 0.08359144693063725
# feature_unreproved_cultish_glioma 0.08152324121023798
# feature_bluff_carbonyl_verbena 0.08129485815526596
# feature_paleolithic_myalgic_lech 0.0644991941409793
# feature_tutelary_mangier_cryoscopy 0.05942112157893632
# feature_spellable_quintic_idiotism 0.057693163203672494
# feature_nappiest_unportioned_readjustment 0.05069492623011717
# feature_pakistan_swirling_dystonia 0.0456967126069317
# feature_gravettian_groveling_crooning 0.045245676648372556
# feature_unsizable_ancestral_collocutor 0.04490687036280116
# feature_cauline_herpetic_videocassette 0.043486215445824705
# feature_waggly_outlandish_carbonisation 0.04343149085192857
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_foldaway_supernumerary_clubhouse 0.23007983067175594
# feature_endoplasmic_inwrought_percival 0.11128305216368439
# feature_dysuric_permeated_makeweight 0.0932329629995226
# feature_anxiolytic_placatory_sextile 0.07328955936264503
# feature_sicker_spelaean_endplay 0.07243091626181147
# feature_stockish_overland_potentiation 0.07191296774809625
# feature_clavate_geriatric_aldebaran 0.05332199300661862
# feature_agee_sold_microhabitat 0.046937394962576415
# feature_balinese_uncomforted_mimicker 0.043682814300524245
# feature_detrital_respected_parlance 0.0422768655490671
# feature_unbarking_apolitical_hibernian 0.03860588502007305
# feature_excaudate_laboured_loquitur 0.036785636470833924
# feature_inlaid_defensible_gladiator 0.032286510336802
# feature_antarthritic_syzygial_wonderland 0.03186444543982651
# feature_twittery_tai_attainment 0.02200916570616246
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_driven_preserving_spectroheliogram 0.11526700402193148
# feature_blinded_memorable_wring 0.08868212528466818
# feature_monarchic_blah_cellarman 0.08470828617830331
# feature_rival_undepraved_countermarch 0.08115421076533352
# feature_banal_microanalytical_posset 0.08044021378347345
# feature_expended_evitable_darwinian 0.07530715738202963
# feature_cavitied_alleviatory_neuk 0.0703352072375574
# feature_just_flavescent_draff 0.06663159598457187
# feature_pulverable_unpolitical_bathometer 0.0600517015598763
# feature_mantuan_cricoid_responder 0.04899052626475051
# feature_etched_furry_biriani 0.04841701988663721
# feature_unsapped_anionic_catherine 0.046984294818975106
# feature_store_comforted_goiter 0.046837598301152465
# feature_vibratory_prejudicial_quadrillion 0.04465587841806559
# feature_uremic_trussed_grater 0.041537180112673905
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_cauline_herpetic_videocassette 0.09082174933380972
# feature_unrecognisable_waxier_paging 0.08772931617081742
# feature_uncomplying_unprovocative_ochlophobia 0.08616365254472598
# feature_huggable_interim_doline 0.0789473842590813
# feature_anxiolytic_placatory_sextile 0.07387908463778692
# feature_unadjusted_dissectible_warley 0.07258347146837481
# feature_prostate_kernelly_chromogen 0.06846567897901529
# feature_coated_transitory_oersted 0.0666146478552187
# feature_yeasty_castilian_nicaragua 0.06433108375856557
# feature_rifled_mum_ova 0.06246005066607192
# feature_smuggled_scarabaeoid_fastball 0.05429325932873988
# feature_heedful_argyle_russianization 0.054232943625934574
# feature_enzymatic_poorest_advocaat 0.04879237875916015
# feature_coloratura_preclusive_micromillimetre 0.04819664647704564
# feature_guardant_giocoso_natterjack 0.04248865213565216
# feature_yelled_hysteretic_eath 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_wounded_crook_gargoylism 0.0
# feature_humanlike_urinant_snuffle 0.08348324980979412
# feature_overrank_shavian_epitaxy 0.0811076134974809
# feature_preoral_tonsorial_souk 0.07745307271950563
# feature_unutterable_softening_roper 0.07444774556581706
# feature_endoplasmic_inwrought_percival 0.06851681001994102
# feature_evocable_woollen_guarder 0.06807908500510361
# feature_mancunian_stalky_charmeuse 0.06624615700008164
# feature_permed_steady_adminicle 0.06578057908283352
# feature_unmethodized_straining_heartburning 0.06537598420357597
# feature_coalier_hircine_brokerage 0.06528665626859853
# feature_wordiest_babist_stackyard 0.06349012387439368
# feature_undealt_tonal_fictionalization 0.06312365837168517
# feature_brief_optimistic_consentaneity 0.05496447726900764
# feature_unconfessed_paltry_finn 0.052238776054725045
# feature_phyllopod_unconstrainable_blubberer 0.05040601125745637
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_sciurine_stibial_lintwhite 0.10942766911482511
# feature_unplumb_prefectorial_gloucester 0.10049267342921456
# feature_flawy_caller_superior 0.08826290859807982
# feature_spicier_unstripped_initial 0.0845545814971037
# feature_aeolic_downy_forefinger 0.06325181903065788
# feature_disclosed_transcendental_pungency 0.06299391598471699
# feature_squabbiest_receivable_foreyard 0.06199207889616662
# feature_bluff_carbonyl_verbena 0.0601603128548601
# feature_uneducated_afraid_sip 0.05955258732475893
# feature_unalloyed_carminative_supercargo 0.058458871917682634
# feature_sunburnt_sympodial_cookhouse 0.05487914179353434
# feature_smashed_gynaecoid_septa 0.051877417155067405
# feature_proteinic_marcan_anxiety 0.05144611051014235
# feature_evocable_woollen_guarder 0.0469412750794017
# feature_marxian_plated_refrigeration 0.04570863681378781
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_incorporating_abominable_daily 0.10006918042006795
# feature_endogamic_suasible_boasting 0.09760603224328321
# feature_rude_booziest_ilium 0.08221639718270105
# feature_pennsylvanian_sibylic_chanoyu 0.07606695289350462
# feature_mediative_sufferable_serosity 0.0715504046720447
# feature_winglike_hydropathic_sedimentology 0.06662785331894741
# feature_bootleg_clement_joe 0.06598492315801029
# feature_lamplit_unengaged_mommy 0.06364558210336818
# feature_versicular_buoyant_codetta 0.06347262688149702
# feature_dissymmetric_stressed_stonewalling 0.05894421692003186
# feature_totipalmate_rightable_occultist 0.05733256589710233
# feature_acclimatisable_unfeigned_maghreb 0.0526624367669051
# feature_packaged_topological_paradigm 0.05095644490476938
# feature_translucid_neuroanatomical_sego 0.05087079711103778
# feature_expended_evitable_darwinian 0.04199358552672908
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_wrathful_prolix_colotomy 0.1064812391838187
# feature_hierologic_expectable_maiolica 0.10381005249988476
# feature_lentissimo_ducky_quadroon 0.10326932294794147
# feature_uncropped_tipsier_postulator 0.07968507075971092
# feature_francophone_lattermost_spohr 0.07831120819100784
# feature_ferial_incumbent_engraving 0.06983168651202372
# feature_pulmonic_bladed_affray 0.06939863398554207
# feature_crapulent_appropriate_kanga 0.0667343590729143
# feature_sophistic_translucid_abutment 0.06323799588313554
# feature_digressive_ratty_supernatant 0.06312987235486134
# feature_navigational_enured_condensability 0.06255780640053492
# feature_parturient_liberian_gamal 0.06200298536251429
# feature_enervated_tearier_septation 0.05410951117737076
# feature_normal_urochordal_proffer 0.012074023155281072
# feature_hardback_saturnalian_cyclometer 0.005366232513458235
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wounded_crook_gargoylism 0.0
# feature_reverable_sunk_quiet 0.09333426673860969
# feature_squirarchal_bioplasmic_delay 0.08959476069610127
# feature_overrank_shavian_epitaxy 0.0756930012015805
# feature_undealt_tonal_fictionalization 0.07161421429730212
# feature_antimonarchist_ordainable_quarterage 0.06926773699448885
# feature_eighteen_kafka_segno 0.06524149902213994
# feature_permed_steady_adminicle 0.06431394090357055
# feature_ultra_unpolluted_adsorbent 0.06268687041518382
# feature_unmethodized_straining_heartburning 0.0621482428571947
# feature_legged_spatiotemporal_basalt 0.06199127334307025
# feature_admissive_jaggiest_yabby 0.06190462644897984
# feature_tricksome_unimproved_accidental 0.060374851178128755
# feature_southernmost_unhuman_arbiter 0.060224916731917426
# feature_laniary_chelated_rejoicing 0.05855033909110472
# feature_crapulent_appropriate_kanga 0.043059460080627686
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_anucleate_knotted_nonage 0.251609167878986
# feature_crispy_neighboring_jeffersonian 0.1390807474486977
# feature_relinquished_incognizable_batholith 0.11142533988639353
# feature_coraciiform_sciurine_reef 0.05513004133481847
# feature_acetose_periotic_coronation 0.052114862530653595
# feature_convalescence_deuteranopic_lemuroid 0.0510746960996032
# feature_stratocratic_aerodynamic_herero 0.050804261712516355
# feature_adverbial_inexplicable_schul 0.04753254070598541
# feature_froggier_unlearned_underworkman 0.047087467466543104
# feature_dexter_unstifled_snoring 0.042767358889694476
# feature_nappiest_unportioned_readjustment 0.042536892807502204
# feature_insipid_unshakable_panne 0.03863791733344668
# feature_corniest_undue_scall 0.03555969811192334
# feature_incredible_plane_sacque 0.034639007793235865
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_wounded_crook_gargoylism 0.0
# feature_ecstatic_foundational_crinoidea 0.33103486805942867
# feature_relinquished_incognizable_batholith 0.08927219247117497
# feature_bricky_runed_bottleful 0.06670137096295409
# feature_diametral_inflatable_editorialization 0.056662085423254106
# feature_waggly_outlandish_carbonisation 0.048206056399197866
# feature_singhalese_cerographical_ego 0.04815099529769959
# feature_ichthyotic_roofed_yeshiva 0.04751041937178205
# feature_depressant_blinded_yellowstone 0.046297966064832
# feature_entopic_interpreted_subsidiary 0.04411288952384416
# feature_jangly_weedier_bhang 0.04038472847000004
# feature_guttering_half_spondee 0.040113942875913244
# feature_coated_transitory_oersted 0.03852362334878371
# feature_geomorphological_uncompanioned_colander 0.0381671128628267
# feature_solemn_wordier_needlework 0.03753845862275816
# feature_profaned_exothermal_orczy 0.027323290245550542
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_styloid_subdermal_cytotoxin 0.21304259300936637
# feature_crispy_neighboring_jeffersonian 0.1773047834430938
# feature_genic_knobbed_malacologist 0.15632419577677922
# feature_driven_preserving_spectroheliogram 0.06648609751401902
# feature_triangled_rubber_skein 0.06495862365598344
# feature_crooked_wally_lobation 0.060957430275832364
# feature_unmanaged_amative_grog 0.05575857292974145
# feature_interchangeable_yellow_thinker 0.04128704182091481
# feature_gubernacular_liguloid_frankie 0.03237411512122772
# feature_grasping_unmetrical_trollopian 0.03223652975251735
# feature_blinded_memorable_wring 0.030028041778724052
# feature_irrevocable_unlawful_oral 0.029859068716397548
# feature_exhibitionist_bicuspidate_goalpost 0.022906391671225095
# feature_reverable_sunk_quiet 0.016476514534177797
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_wounded_crook_gargoylism 0.0
# feature_exhaling_awkward_inhabitant 0.28341315626887204
# feature_genic_knobbed_malacologist 0.11511862956265896
# feature_anucleate_knotted_nonage 0.07622860156491947
# feature_dressy_skiable_hypognathism 0.07220908017423402
# feature_improbable_pouched_gaitskell 0.0669195283636506
# feature_suppressed_unremovable_telephone 0.0496486050993617
# feature_impeded_propagandist_darer 0.04876340322359517
# feature_eighteen_kafka_segno 0.04709026269699766
# feature_percipient_atelectatic_cinnamon 0.044465839810073404
# feature_grimmest_prostate_doctrinaire 0.04060512716508574
# feature_checkered_accoutred_marjoram 0.04003720935772658
# feature_guardant_giocoso_natterjack 0.031928222052884765
# feature_mimetic_sprawly_flue 0.02980578339799121
# feature_stoichiometric_unanswerable_leveller 0.027071766785060562
# feature_epicontinental_centum_raine 0.026694784476888157
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_foldaway_supernumerary_clubhouse 0.21265669546987057
# feature_endoplasmic_inwrought_percival 0.1050666711738413
# feature_monarchic_blah_cellarman 0.07914037954434064
# feature_stockish_overland_potentiation 0.07835353369741471
# feature_crispy_neighboring_jeffersonian 0.07165013425759136
# feature_dysuric_permeated_makeweight 0.0701597780645282
# feature_wordiest_babist_stackyard 0.06538136117089884
# feature_tearing_unkingly_adulthood 0.05411514678480489
# feature_anxiolytic_placatory_sextile 0.0538129101991323
# feature_instructional_desensitized_symmetallism 0.04442448004448422
# feature_scombroid_genoese_kilojoule 0.0442574796841502
# feature_fungible_allotted_deterioration 0.03709513299250745
# feature_hefty_hesitant_mantissa 0.03223595045785073
# feature_deformable_productile_piglet 0.030501027035248537
# feature_enzymatic_poorest_advocaat 0.021149319423336057
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_stalagmitic_jacobethan_campanologist 0.09546200471918874
# feature_expended_evitable_darwinian 0.09056552607681082
# feature_corniest_undue_scall 0.07874393936394958
# feature_ironfisted_nonvintage_chlorpromazine 0.0774932596357297
# feature_crimpier_gude_housedog 0.0659594304878831
# feature_subglobose_sleekier_calcaneum 0.06570757559490538
# feature_tineal_premarital_rya 0.06477581022555756
# feature_tangled_dropsical_uprooter 0.06408397826879694
# feature_eleatic_fellow_auctioneer 0.06205827347982645
# feature_pulmonate_descendant_epiblast 0.06006851024797362
# feature_baptist_undelayed_mannerism 0.05881210647677421
# feature_twittery_tai_attainment 0.057364534753010864
# feature_unlivable_armenian_wedge 0.056416084042052436
# feature_planular_naturistic_pinhead 0.05204461811547579
# feature_heliotypic_deprivative_behavior 0.05044434851206477
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_completive_pedantical_sinecurist 0.1153121120061965
# feature_desensitizing_distributive_bidder 0.0898309894929777
# feature_ungenuine_sporophytic_evangelist 0.08671602109718077
# feature_dividual_kufic_militarism 0.08263816636175941
# feature_paleolithic_myalgic_lech 0.08263813883676246
# feature_subfusc_furriest_nervule 0.07922445697059775
# feature_trad_unreduced_banian 0.07404589522380803
# feature_riskier_ended_typo 0.05757660649194952
# feature_prepotent_divorced_taffy 0.05687507957082537
# feature_undepreciated_partitive_ipomoea 0.05558828670665374
# feature_fogyish_cruciate_starter 0.053806311601075955
# feature_translative_quantitative_eschewer 0.04615702279896261
# feature_unplumb_prefectorial_gloucester 0.040727544192189054
# feature_supererogatory_unleisured_kitling 0.040536558141445
# feature_hefty_hesitant_mantissa 0.03832681050761625
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_nonagenarian_roundish_publication 0.11877757114976895
# feature_protractive_moral_forswearing 0.1070980555871846
# feature_obligate_quadruplication_feathering 0.08265633919214253
# feature_libratory_seizable_orlando 0.08175669954600957
# feature_aquaphobic_paradisal_isagoge 0.06854306900524908
# feature_recreational_homiletic_nubian 0.06623774342207754
# feature_incertain_catchable_zibet 0.06595936451375076
# feature_cockiest_ditheistical_pennyworth 0.06316192948657359
# feature_tricksiest_pending_voile 0.05562075141085795
# feature_croaking_japhetic_fifer 0.055417831410953
# feature_lateral_confervoid_belgravia 0.05521711367959779
# feature_squirarchal_bioplasmic_delay 0.05054027452671005
# feature_homelike_telltale_silvan 0.04650410537928144
# feature_prepotent_divorced_taffy 0.0459398527329909
# feature_massive_demisable_spouse 0.036569298956852174
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_sumerian_descendible_kalpa 0.0915602732165282
# feature_translative_quantitative_eschewer 0.09148978406664493
# feature_veristic_parklike_halcyon 0.08374781691899913
# feature_tinkly_driftiest_maurya 0.08084711393647223
# feature_unsympathetic_classic_abac 0.07812249568705075
# feature_ironclad_coppery_labour 0.06743032364623941
# feature_constrained_disused_perishable 0.06392699317903261
# feature_pourable_multangular_requisition 0.062337391686789666
# feature_bluff_carbonyl_verbena 0.061760246899272425
# feature_manufactured_nodal_seeking 0.06172423573880135
# feature_developing_behind_joan 0.05720205381901443
# feature_glibber_deficient_jakarta 0.056304772105656105
# feature_agricultural_uranic_ankerite 0.05579881391065637
# feature_solemn_wordier_needlework 0.05247142291100285
# feature_endogamic_suasible_boasting 0.03527626227783961
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
# feature_glial_birefringent_popery 0.11274857054559237
# feature_endogamic_suasible_boasting 0.09166652038383787
# feature_unconfessed_paltry_finn 0.08176809685504496
# feature_twistable_comely_licensee 0.0732627051377426
# feature_gubernacular_liguloid_frankie 0.07085844781946314
# feature_unsoaped_waspier_much 0.07076001301311857
# feature_ethiopic_anhedonic_stob 0.06763344671449151
# feature_baggier_supernormal_calcedony 0.06607506882592687
# feature_preceptive_rushed_swedenborgian 0.06391804180888287
# feature_approximal_telautographic_sharkskin 0.0612707865957084
# feature_daytime_arching_expropriator 0.059816628527692955
# feature_ugly_admissible_firm 0.048209202875344
# feature_paleolithic_myalgic_lech 0.04484335626327313
# feature_quaternate_loftier_directorate 0.043957873026250656
# feature_leaky_overloaded_rhodium 0.043211241607630096
# feature_yelled_hysteretic_eath 0.0
# feature_yeasty_castilian_nicaragua 0.0
# feature_wuthering_stinky_bimetallist 0.0
# feature_wrought_muckier_temporality 0.0
# feature_wrathful_prolix_colotomy 0.0
#                  Targets  CrossValScoresMean    Scores
# 0                 target           -0.067237 -0.057654
# 1      target_nomi_v4_20           -0.067237 -0.057654
# 2      target_nomi_v4_60           -0.088026 -0.071267
# 3    target_jerome_v4_20           -0.014904  0.005457
# 4    target_jerome_v4_60           -0.045602 -0.057340
# 5     target_janet_v4_20           -0.095440 -0.034622
# 6     target_janet_v4_60           -0.104530 -0.041977
# 7       target_ben_v4_20           -0.085541 -0.031720
# 8       target_ben_v4_60           -0.051766 -0.075929
# 9      target_alan_v4_20           -0.087289 -0.047475
# 10     target_alan_v4_60           -0.069706 -0.048152
# 11     target_paul_v4_20           -0.006648  0.039051
# 12     target_paul_v4_60           -0.013504  0.005817
# 13   target_george_v4_20            0.038210  0.051182
# 14   target_george_v4_60            0.003172  0.029321
# 15  target_william_v4_20           -0.041106  0.008721
# 16  target_william_v4_60           -0.074425 -0.059263
# 17   target_arthur_v4_20           -0.096096 -0.050975
# 18   target_arthur_v4_60           -0.113794 -0.081988
# 19   target_thomas_v4_20           -0.080536 -0.030266
# 20   target_thomas_v4_60           -0.072575 -0.042716

# %% [markdown]
# As shown above, we can see that each target, has around **14-18 important predictors** that make up the decision tree. **This means that, out of the 1191 features, only a tiny amount really matter!**
#
# Following that, we have our cross validation scores, for each target along with the **r^2 score**, which indicate some **negative correlation**, where the model is indicating it isnt fitting as best as it could. <br>
#
# When implementing our decision tree, I tried a varition of max depths from about 4-8, and I continued to see negative scores. This indicates that our model is not properly fitting, and we need to add regularization techniques, or use a GridSearch to help us understand the best parameters for our model as our baseline model indicated positive results. This can help as we are running 21 decision trees at once and can be time consuming. By finding the best model parameters, we can then compare this to our 2nd era.

# %% [markdown]
# ### The chance model
# We know that each era's target is distributed perfectly like so:

# %%
era_1_df_target_counts = era_1_df.get(['feature_divulsive_explanatory_ideologue', 'target']).groupby('target').count().get('feature_divulsive_explanatory_ideologue').to_list()

for i in range(len(era_1_df_target_counts)):
    print(str(np.round(era_1_df_target_counts[i]/sum(era_1_df_target_counts),2)*100)+'%','category',i/4)
# Out:
# 5.0% category 0.0
# 20.0% category 0.25
# 50.0% category 0.5
# 20.0% category 0.75
# 5.0% category 1.0

# %% [markdown]
# Thus the model that predicts class 0.5 each time will achieve a 50% accuracy over an era.
#
# Notice that the above was calculated on era 1. Now let's build the chance model and show that it achieves 50% on era 2. This is trivial, but it still sets the chance baseline.

# %%
def chance_model(X):
    return pd.Series(X.shape[0]*[0.5])

def accuracy(actual, predicted):
    return np.count_nonzero(actual==predicted)/actual.shape[0]

print('The accuracy of the chance model on an era of unseen data is', str(accuracy(y_2.reset_index().get('target'), chance_model(X_2))))
# Out:
# The accuracy of the chance model on an era of unseen data is 0.4984339110461474

# %% [markdown]
# ### The base model
# We will now build the model described in the Proposed Solution section. To recapitulate, a regression is trained, testing data is input batch-style, the percentiles are computed, and the points are classified by which percentiles they fall between. This works because we know the exact distribution of our target.

# %%
reg = sm.OLS(y_1.get('target'), X_1).fit()
era_2_reg_predictions = reg.predict(X_2.reset_index().drop(columns='index'))
era_2_reg_predictions
# Out:
# 0       0.367739
# 1       0.525250
# 2       0.328782
# 3       0.387334
# 4       0.428699
#           ...
# 4784    0.490356
# 4785    0.167735
# 4786    0.455724
# 4787    0.363053
# 4788    0.605544
# Length: 4789, dtype: float64

# %%
era_2_percentiles = [np.percentile(era_2_reg_predictions, i) for i in [5,25,75,95,100]]
def classify_reg_prediction(reg_prediction, percentiles=era_2_percentiles):
    for i in range(5):
        if reg_prediction<=percentiles[i]:
            return i/4

era_2_class_predictions = era_2_reg_predictions.apply(classify_reg_prediction)
print('The accuracy of this model on era 2 data (unseen) is', str(accuracy(y_2.reset_index().get('target'), era_2_class_predictions)))
# Out:
# The accuracy of this model on era 2 data (unseen) is 0.3823345166005429

# %% [markdown]
# This is worse than chance! (50%)

# %% [markdown]
# We now compute the **one-vs-rest accuracy** metric mentioned in the Evaluation Metrics section. Note that this metric is for testing how well a model would have performed if our problem was a 2-class problem, so the accuracies given will be better than the accuracy of the model on the actual problem (2 class accuracy >= 5 class accuracy).

# %%
def one_vs_rest_accuracy(actual, predicted):
    for i in [0, 0.25, 0.50, 0.75, 1]:
        class_accuracy = ((predicted==i) == (actual==i)).sum()/predicted.shape[0]
        print('The one-vs-rest accuracy for class', i, 'was', class_accuracy)
        
one_vs_rest_accuracy(y_2.reset_index().get('target'), era_2_class_predictions)
# Out:
# The one-vs-rest accuracy for class 0 was 0.9150135727709334
# The one-vs-rest accuracy for class 0.25 was 0.7122572562121529
# The one-vs-rest accuracy for class 0.5 was 0.5157652954687826
# The one-vs-rest accuracy for class 0.75 was 0.7047400292336605
# The one-vs-rest accuracy for class 1 was 0.9168928795155565

# %% [markdown]
# These results make it more clear why our model is performing so poorly. The accuracy is great for the smaller classes, but bad for the large class. The large class takes up 50% of the dataset, so if we want to optimize for accuracy, we should pay more attention to it.
#
# We now display the histogram visualizing the **prediction shape**, the distribution of our predictions.

# %%
pd.DataFrame(era_2_class_predictions).plot(kind='hist',density=True);

# %% [markdown]
# Since we made this model to preserve the perfection of the target distribution, the predicted target's shape will of course be of that distribution. This metric is not useful for this model. It will be more useful for other models, where we do not restrict ourselves to this shape. <br>
#
# The problem is that we are training a model (linear regression) that is not immediately optimized for use with this classifier during training time. We must find a better way to take advantage of our knowledge of the target variable shape.

# %% [markdown]
# # Discussion (NEW)
#
# ### Interpreting the result (NEW)
#
# OK, you've given us quite a bit of tech informaiton above, now its time to tell us what to pay attention to in all that.  Think clearly about your results, decide on one main point and 2-4 secondary points you want us to understand. Highlight HOW your results support those points.  You probably want 2-5 sentences per point.
#
# ### Limitations (NEW)
#
# Are there any problems with the work?  For instance would more data change the nature of the problem? Would it be good to explore more hyperparams than you had time for?
#
# ### Ethics & Privacy
# * Privacy
#     * This dataset comes from the Numeri tournament who obfuscates their dataset, to maintain stock company names private. These will be our data points where each datapoint is represented by a unique 16-digit identifier. The features that measure the stock predictions, which we will be using as the variables, are also private where they are labeled as “feature1, feature2, feature 3” etc. This allows us to create an unbiased model, meanwhile protecting private stock and company information.
# * *Ethics
#     * By using obfuscated data, and a model that predicts a single target, some possible ethical concerns can revolve around the hidden data. As these data points are hidden values, we as a team may not truly know what kind of stock information we are predicting and what feature values these may represent. This can be unethical as we may be predicting things that can lead to bias or unfair predictions.
#
# ### Conclusion
#
# Reiterate your main point and in just a few sentences tell us how your results support it. Mention how this work would fit in the background/context of other work in this field if you can. Suggest directions for future work if you want to.

# %% [markdown]
# # Footnotes
#
# 1. [^](#stockinfo_link): O'shea, A. & Davis, C. (3 Mar 2022) What Is the Stock Market and How Does It Work? *nerdwallet*. https://www.nerdwallet.com/article/investing/what-is-the-stock-market <br>
# 2. [^](#priorwork_1): Sharma P. (13 Oct 2021) Machine Learning for Stock Market Prediction with Step-by-Step Implementation. *Analytics Vidhya*. https://www.analyticsvidhya.com/blog/2021/10/machine-learning-for-stock-market-prediction-with-step-by-step-implementation/
# 3. [^](#priorwork_2):  Budiharto W. (11 Mar 2021) Data science approach to stock prices forecasting in Indonesia during Covid-19 using Long Short-Term Memory (LSTM). *SpringerOpen*. https://journalofbigdata.springeropen.com/articles/10.1186/s40537-021-00430-0
# 4. [^](#priorwork_3): Sharma A., Bhuriya D., Singh U. (20-22 April 2017) Survey of stock market prediction using mahcine learning approach. *IEEE Xplore*. https://ieeexplore.ieee.org/abstract/document/8212715?casa_token=b3ZFWmFhw5MAAAAA:iy94X3E3wlSJIGcejGgc2XqA_ybH8UvzbdtEpbHY1qIb_d0hFJLQEllB-7LheR5T_73V7mckIw
# 5. [^](#priorwork_4): Parmar I., Agarwal N., Saxena S., Arora R., Gupta S., Dhiman H., Chouhan L. (15-17 Dec 2018) Stock Market Prediction Using Machine Leanring. *IEEE*. https://ieeexplore.ieee.org/abstract/document/8703332?casa_token=v5atTBZIRIkAAAAA:t1j5GRm9PFXT-ihgeClRFMb_c7rcQrAHgzkiklBsmIBQeTblFuGPqJP90MQNbJz8zSeUV5x5Yw
# 6. [^](#priorwork_5): Khattak A., Ullah H., Khald H., Habib A., Asghar M., Kundi F. (04 Dec 2019) Stock Market Trend Prediction using Supervised Learning. *Association for Computing Machinary*. https://dl.acm.org/doi/abs/10.1145/3368926.3369680?casa_token=d2V4AVyFf5wAAAAA:R2myhseJNw6CBOTtrqsEzKvXlhw9hcul0RCdlUX8uCCMEHr7zMq2mVr2V9BKJ08W1Z-izV6h9NYo
# 7. [^](#Numerai_Info): Numerai, Numerai Tournament Overview. *Numerai* https://docs.numer.ai/tournament/learn
